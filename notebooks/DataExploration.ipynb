# %%
# %load_ext autoreload
# %autoreload 2

# %%
from visualise import read_csv, generate_transposed_dict, visualize_distribution

# %%
path_attacks = '../data/2024-adatelemzo-msc/ddos_data.attacks.anonimized.csv'
path_vectors = '../data/2024-adatelemzo-msc/ddos_data.vectors.anonimized.csv'

csv_data_attacks = read_csv(path_attacks)
csv_data_vectors = read_csv(path_vectors)

headers_data_attacks = list(csv_data_attacks[0].keys())
headers_data_vectors = list(csv_data_vectors[0].keys())

# %%
occurance_stats_attacks = generate_transposed_dict(csv_data_attacks)
occurance_stats_vectors = generate_transposed_dict(csv_data_vectors)

print_stat = lambda data : [print("{:10} different values for key:\t\'{}\'".format(len(set(values)), key)) for key, values in data.items()]

print('\nData on attacks:')
print_stat(occurance_stats_attacks)
print('\nData on vectors:')
print_stat(occurance_stats_vectors)
# Out:
# Data on attacks:
#     134770 different values for key:	'Attack ID'
#          1 different values for key:	'Card'
#      18200 different values for key:	'Victim IP'
#      29624 different values for key:	'Port number'
#         47 different values for key:	'Attack code'
#        461 different values for key:	'Detect count'
#          2 different values for key:	'Significant flag'
#      16241 different values for key:	'Packet speed'
#        606 different values for key:	'Data speed'
#       1269 different values for key:	'Avg packet len'
#        315 different values for key:	'Avg source IP count'
#     127985 different values for key:	'Start time'
#     127918 different values for key:	'End time'
#          2 different values for key:	'Whitelist flag'
#          3 different values for key:	'Type'
#
# Data on vectors:
#     134769 different values for key:	'Attack ID'
#      12534 different values for key:	'Detect count'
#          1 different values for key:	'Card'
#      18200 different values for key:	'Victim IP'
#      34137 different values for key:	'Port number'
#         48 different values for key:	'Attack code'
#          2 different values for key:	'Significant flag'
#       6173 different values for key:	'Packet speed'
#       1523 different values for key:	'Data speed'
#       1447 different values for key:	'Avg packet len'
#       2658 different values for key:	'Source IP count'
#     528045 different values for key:	'Time'
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
visualize_distribution(occurance_stats_attacks)
# Out:
# Attack ID
# Victim IP
# Port number
# Detect count
# Packet speed
# Data speed
# Avg packet len
# Avg source IP count
# Start time
# End time
